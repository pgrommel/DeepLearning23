# %% [markdown]
# # Build basic 2-Layer MLP to solve the xor-Problem

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs #for data generatio

# %%
X, y = make_blobs(n_samples=100, n_features=2, cluster_std=.1
                  ,centers= [(1,1), (1,0), (0,0),(0,1)])

# %%
y[y==2]=0
y[y==3]=1

# %%
plt.scatter(X[:,0],X[:,1],c=y)

# %% [markdown]
# ## Steps:
# * draw netwok - how many neuron per layer are needed, how many Perceptrons per layer?
# * think in terms of splitting the data by linear planes, do not use non-linear activations
